# %% [markdown]
# # Preprocess the raw survey data
#
# Saves a cleaned version of the survey data to be used in analysis and that can be publicly published (is IRB compliant).
#
# Keeps only data from participants who:
#
# - Have valid Prolific IDs
# - Completed the survey
# - Passed ALL attention checks
#
# Keeps only the data columns necessary for analysis.
# Drops:
# - Prolific ID (privacy risk)
# - Unneeded qualtrics metadata
#
# Saves fields metadata to a separate file and drops this metadata from the saved cleaned data.

# %%
import numpy as np
import pandas as pd

raw_data_filepath = '../data/sample-raw.csv'
cleaned_data_filepath = '../data/sample-preprocessed.csv'
fields_filepath = '../data/fields.csv'

# %%
df = pd.read_csv(raw_data_filepath, dtype='str')
print(df.shape)
# Out:
# (4029, 850)

# %% [markdown]
# Can immediately drop the columns never used that were added by Qualtrics.

# %%
drop_cols = [
    'StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
    'RecipientLastName', 'RecipientFirstName', 'RecipientEmail', 'ExternalReference', 
    'LocationLatitude', 'LocationLongitude', 'DistributionChannel', 
    'UserLanguage',
    # use PROLIFIC_PID instead which is set as embedded data via a URL parameter
    'Q_PROLIFIC_PID',
]
df = df.drop(drop_cols, axis=1)

# %%
non_choice_fields = [f for f in df.columns if not (f.startswith('CHOICE_'))]
print(list(non_choice_fields))
df[non_choice_fields].drop([1]).drop(['PROLIFIC_PID'], axis=1).head()
# Out:
# ['Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId', 'Q-attn-number-21', 'Q_online_shopping', 'Q_takeout_food', 'Q_online_groceries', 'Q_habits_attn_check', 'Q_v_0_why_no', 'Q_v_0_why_no_4_TEXT', 'Q_v_1', 'Q_v_1_why_no', 'Q_v_1_why_no_4_TEXT', 'Q_v_2', 'Q_v_2_why_no', 'Q_v_2_why_no_4_TEXT', 'Q_v_attn_check_1', 'Q_gender', 'Q_age', 'Q_race', 'Q_income', 'Q_urban_rural', 'Q_residence_type', 'Q_residence_type_3_TEXT', 'Q_state', 'Q_comments', 'PROLIFIC_PID', 'STUDY_ID', 'online_shopping', 'takeout_food_delivery', 'online_groceries', 'prescription_medications_delivery', 'last_minute_groceries_delivery', 'liquor_store_delivery', 'questions_asked']
#    Duration (in seconds)  Finished         RecordedDate         ResponseId  \
# 0  Duration (in seconds)  Finished        Recorded Date        Response ID
# 2                    128         1  2022-09-12 08:14:07  R_2chgn4rkY4fPpOO
# 3                     91         1  2022-09-12 08:16:36  R_237SFIQ3gnVTXpg
# 4                    262         1  2022-09-12 08:25:22  R_2zUNSdeQI7uzbbu
# 5                    129         1  2022-09-12 08:33:47  R_3DbUHlWnnu89bWC
#
#                   Q-attn-number-21  \
# 0  Please select the number shown.
# 2                               21
# 3                               21
# 4                               21
# 5                               21
#
#                                    Q_online_shopping  \
# 0  How often (on average) do you make online shop...
# 2                                                  3
# 3                                                  5
# 4                                                  4
# 5                                                  5
#
#                                       Q_takeout_food  \
# 0  How often (on average) do you have take-out fo...
# 2                                                  3
# 3                                                  2
# 4                                                  2
# 5                                                  1
#
#                                   Q_online_groceries  \
# 0  How often (on average) do you purchase your gr...
# 2                                                  3
# 3                                                  5
# 4                                                  5
# 5                                                  5
#
#                                  Q_habits_attn_check  \
# 0  How closely are you paying attention? This is ...
# 2                                                  5
# 3                                          1,2,3,4,5
# 4                                          1,2,3,4,5
# 5                                          1,2,3,4,5
#
#                                         Q_v_0_why_no  ...  \
# 0  What are your reasons for never ordering     t...  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
# 5                                                NaN  ...
#
#                            Q_state  \
# 0  50 States, D.C. and Puerto Rico
# 2                              NaN
# 3                               22
# 4                               22
# 5                               22
#
#                                           Q_comments  \
# 0  Thank you for taking the survey. When you cont...
# 2                                                NaN
# 3                                                NaN
# 4                    alex test -- take-out food only
# 5                       geoffrey test - takeout only
#
#                    STUDY_ID  online_shopping  takeout_food_delivery  \
# 0                  STUDY_ID  online_shopping  takeout_food_delivery
# 2  62facea5645985d77801fd22             True                   True
# 3  62facea5645985d77801fd22             True                   True
# 4  62facea5645985d77801fd22             True                   True
# 5  62facea5645985d77801fd22             True                   True
#
#    online_groceries  prescription_medications_delivery  \
# 0  online_groceries  prescription_medications_delivery
# 2              True                               True
# 3             False                               True
# 4             False                              False
# 5             False                              False
#
#    last_minute_groceries_delivery  liquor_store_delivery  questions_asked
# 0  last_minute_groceries_delivery  liquor_store_delivery  questions_asked
# 2                            True                   True              NaN
# 3                           False                  False              NaN
# 4                           False                  False               12
# 5                           False                  False               12
#
# [5 rows x 35 columns]

# %% [markdown]
# Save the fields metadata (rows 0,1) in case someone wants them for easy reference later.
#
# Do not save the choice Q's in the fields data.
#
# Then drop metadata from the preprocessed data.

# %%
fields_df = df[non_choice_fields].loc[0].rename('field').to_frame()
fields_df
# Out:
#                                                                                field
# Duration (in seconds)                                          Duration (in seconds)
# Finished                                                                    Finished
# RecordedDate                                                           Recorded Date
# ResponseId                                                               Response ID
# Q-attn-number-21                                     Please select the number shown.
# Q_online_shopping                  How often (on average) do you make online shop...
# Q_takeout_food                     How often (on average) do you have take-out fo...
# Q_online_groceries                 How often (on average) do you purchase your gr...
# Q_habits_attn_check                How closely are you paying attention? This is ...
# Q_v_0_why_no                       What are your reasons for never ordering     t...
# Q_v_0_why_no_4_TEXT                What are your reasons for never ordering     t...
# Q_v_1                              Suppose there is a company that specializes in...
# Q_v_1_why_no                       What are your reasons for never ordering     m...
# Q_v_1_why_no_4_TEXT                What are your reasons for never ordering     m...
# Q_v_2                              Would you ever order items from a liquor store...
# Q_v_2_why_no                       What are your reasons for never ordering     p...
# Q_v_2_why_no_4_TEXT                What are your reasons for never ordering     p...
# Q_v_attn_check_1                   Suppose this is an attention check. Given this...
# Q_gender                                                        What is your gender?
# Q_age                                                              What is your age?
# Q_race                             Choose one or more races that you consider you...
# Q_income                           What was your entire household income in the p...
# Q_urban_rural                                   Which best describes where you live?
# Q_residence_type                   What type of residence do you live in? - Selec...
# Q_residence_type_3_TEXT            What type of residence do you live in? - Other...
# Q_state                                              50 States, D.C. and Puerto Rico
# Q_comments                         Thank you for taking the survey. When you cont...
# PROLIFIC_PID                                                            PROLIFIC_PID
# STUDY_ID                                                                    STUDY_ID
# online_shopping                                                      online_shopping
# takeout_food_delivery                                          takeout_food_delivery
# online_groceries                                                    online_groceries
# prescription_medications_delivery                  prescription_medications_delivery
# last_minute_groceries_delivery                        last_minute_groceries_delivery
# liquor_store_delivery                                          liquor_store_delivery
# questions_asked                                                      questions_asked

# %%
print('saving fields to file %s' % fields_filepath)
fields_df.to_csv(fields_filepath)
# Out:
# saving fields to file ../data/fields.csv

# %% [markdown]
# Drop participants' data based on exclusion criteria.

# %%
df = df.drop([0,1])
starting_respondent_N = df['ResponseId'].nunique()
print('N=%s total responses before data cleaning' % starting_respondent_N)
df.drop(['PROLIFIC_PID'], axis=1).head(3)
# Out:
# N=4027 total responses before data cleaning
#   Duration (in seconds) Finished         RecordedDate         ResponseId  \
# 2                   128        1  2022-09-12 08:14:07  R_2chgn4rkY4fPpOO
# 3                    91        1  2022-09-12 08:16:36  R_237SFIQ3gnVTXpg
# 4                   262        1  2022-09-12 08:25:22  R_2zUNSdeQI7uzbbu
#
#   Q-attn-number-21 Q_online_shopping Q_takeout_food Q_online_groceries  \
# 2               21                 3              3                  3
# 3               21                 5              2                  5
# 4               21                 4              2                  5
#
#   Q_habits_attn_check Q_v_0_why_no  ... Q_state  \
# 2                   5          NaN  ...     NaN
# 3           1,2,3,4,5          NaN  ...      22
# 4           1,2,3,4,5          NaN  ...      22
#
#                         Q_comments                  STUDY_ID online_shopping  \
# 2                              NaN  62facea5645985d77801fd22            True
# 3                              NaN  62facea5645985d77801fd22            True
# 4  alex test -- take-out food only  62facea5645985d77801fd22            True
#
#   takeout_food_delivery online_groceries prescription_medications_delivery  \
# 2                  True             True                              True
# 3                  True            False                              True
# 4                  True            False                             False
#
#   last_minute_groceries_delivery liquor_store_delivery questions_asked
# 2                           True                  True             NaN
# 3                          False                 False             NaN
# 4                          False                 False              12
#
# [3 rows x 835 columns]

# %%
TEST_PROLIFIC_IDS = [
    '62a2a94d2c2d3cac1cdb636b',
    '62fac4a55e4fc878ec1b0c76',
]
# only include responses completed by Prolific participants
N_PROLIFIC_PID_na = len(df[df['PROLIFIC_PID'].isna()])
print('dropping %s non PROLIFIC responses' % N_PROLIFIC_PID_na)
df = df[df['PROLIFIC_PID'].notna()]
N_uncompleted = len(df[df['Finished'] != '1'])
df = df[df['Finished'] == '1']
print('dropping %s incomplete responses' % N_uncompleted)
# Remove the test responses filled out by us
N_test = len(df[df['PROLIFIC_PID'].isin(TEST_PROLIFIC_IDS)])
print('dropping %s test responses' % N_test)
df = df[~df['PROLIFIC_PID'].isin(TEST_PROLIFIC_IDS)]
print('%s completed responses' % len(df))
# Out:
# dropping 0 non PROLIFIC responses
# dropping 2 incomplete responses
# dropping 9 test responses
# 4016 completed responses

# %%
def passed_attn_checks(row):
    try:
        if row['Q-attn-number-21'] != '21':
            print('%s : %s %s' % (row['PROLIFIC_PID'], row['ResponseId'], 'failed Q-attn-number-21'))
            return False
        if (str(row['Q_habits_attn_check']) == 'nan') or (len(row['Q_habits_attn_check'].split(',')) != 5):
            print('%s : %s %s' % (row['PROLIFIC_PID'], row['ResponseId'], 'failed Q_habits_attn_check'))
            return False
        if row['Q_v_attn_check_1'] in ['1','2']: # only selected 1 option - either 1 or 2
            print('%s : %s %s' % (row['PROLIFIC_PID'], row['ResponseId'], 'failed Q_v_attn_check_1'))
            return False
    except Exception as e:
        print('exception for %s : %s' % (row['PROLIFIC_PID'], row['ResponseId']))
        raise e
    return True

# %%
df['passed_attn_checks'] = df.apply(passed_attn_checks, axis=1)
passed_attn_checks_ResponseId_list = list(df[df.passed_attn_checks == True].ResponseId)
pass_rate = len(passed_attn_checks_ResponseId_list)/len(df)
print('%0.2f = %s/%s respondents passed all attention checks' % (
    pass_rate, len(passed_attn_checks_ResponseId_list), len(df)))
# passed_attn_checks_ResponseId_list
# Out:
# 5a8599792a842c0001fcbacb : R_25QqBuJ38NHBT9s failed Q-attn-number-21
# 5c832bd24b0de2001b3510fc : R_1PdBN81pQZz10MZ failed Q_v_attn_check_1
# 5f490d10022f3f2e8f33cc9a : R_1jp41iLW1oDOfxM failed Q_v_attn_check_1
# 610f7619672322f2c0c98396 : R_BD6TwN3suFU9hjb failed Q_v_attn_check_1
# 5eee7448b465303350093b53 : R_6XslJdUp7GN3B85 failed Q_v_attn_check_1
# 6010f9387969064a53ea6b69 : R_3g7uNDwWjSesDES failed Q_v_attn_check_1
# 5786d6076475d400015a959e : R_PUGtyOIfzxv8KoF failed Q-attn-number-21
# 631bcfaa7faf35d3abb91cbc : R_2Vr9PYvpwZPWJYT failed Q_v_attn_check_1
# 5bc11bbbc11e1200018dfa3b : R_XG1xQ7XxoDMEjIJ failed Q_v_attn_check_1
# 60fdc45f0ae9e5d153012de9 : R_2f3vUv8pwovPJuS failed Q_v_attn_check_1
# 6313bca352b1b9dacd2446e5 : R_1da7BFtzV6chf9W failed Q_v_attn_check_1
# 60ddff2cd6cb7a81cdfb6a00 : R_2t3szyR8tQ7NYJ3 failed Q_v_attn_check_1
# 5e7b815adb5aba05af6e6cc7 : R_wN48C2doNom9QOZ failed Q_v_attn_check_1
# 5e833e342598d4053db08f1f : R_25ZSN2jFhmRF7gq failed Q_habits_attn_check
# 61531681e3a3743f9ce59135 : R_1cY4f78BgR6WH3U failed Q_v_attn_check_1
# 61083fca0f3d3cabc65ee16f : R_24Gk2qMPxVhIwQG failed Q_v_attn_check_1
# 5e521a1083e2e42365b3bd67 : R_28NFPdGu9cbIKqa failed Q_v_attn_check_1
# 5c6ac9bc1d9ff70001ab2ee5 : R_eRk4pJwBewHmtRT failed Q-attn-number-21
# 611189c22603acc9bfc10e2d : R_1jMITa4KsxEq9Jx failed Q_v_attn_check_1
# 612e7ef85edba8d26ef96c99 : R_1OQ4bHhzTxcc2Vj failed Q_habits_attn_check
# 6108ce8402170404dfa30946 : R_31SHnn8Qdag1Pf3 failed Q-attn-number-21
# 5c0fa2324324e80001c951c9 : R_r2BDGQrKbGOeubL failed Q_v_attn_check_1
# 5be3237a3193e90001798302 : R_2EiTxA84Zsn9wfS failed Q_v_attn_check_1
# 5e10f9d02d21857cd4d266b8 : R_27BQXN90zhWpKlz failed Q-attn-number-21
# 60b7c559803665ec56ca8b2c : R_3O6wX9Z5m1XPI1n failed Q_v_attn_check_1
# 62bdb88d3de9f262dd8b6e21 : R_T6gNj3edt9JwE5X failed Q_v_attn_check_1
# 61140fbc763ecf6f2de71183 : R_33eUuAAw4GqcHwT failed Q_v_attn_check_1
# 60f1d81960d9ca3a725d65f6 : R_1dmNROlp38EO0Z7 failed Q_v_attn_check_1
# 5ee64e85c682de3a880579c6 : R_ByM3CE9KgFJAMxP failed Q_v_attn_check_1
# 60f8adb9a315f316c3aee425 : R_2fx46BC5FJhz2ni failed Q_v_attn_check_1
# 5f5d348826f900576f6c95f3 : R_3JJViDMGptcxYcg failed Q_v_attn_check_1
# 62e0dcc18007e8ba41769dd8 : R_oXnjky7EkdyNWHT failed Q_v_attn_check_1
# 5ff36928b82e4645fcbc7f10 : R_1F9AhpNUXd5KkWB failed Q_v_attn_check_1
# 5afe338a4256e90001d5c64b : R_296w5URHj9gXt2g failed Q_v_attn_check_1
# 5c6e31540506a200015c3cc5 : R_8CdsCePEXk8RpsZ failed Q_v_attn_check_1
# 60fd0638ea398c6e93d6ba62 : R_2X5v5UEbWBG6Gs0 failed Q_v_attn_check_1
# 60fdc73e9fc2f113dc1ff96d : R_25zTyzKjf4NVPpY failed Q_v_attn_check_1
# 60e792f25e9ab875f9605cf5 : R_1kFCuUN9nd0oIN3 failed Q_v_attn_check_1
# 6172b8bcb0ca871db44b71c9 : R_2SJgJh8Sw3w4n14 failed Q_v_attn_check_1
# 601c2c63f899976cb35c1269 : R_1DpctOgHINoCU2Y failed Q-attn-number-21
# 5e7e2df818ff3207c8846b93 : R_XSyBgOFuo9WPf1v failed Q_habits_attn_check
# 6153fbe07b967391f75fce87 : R_2pXYP9y3QkULSkR failed Q_v_attn_check_1
# 62e31a9ce71b2e2da6fafbd4 : R_1mJFsASL5qmr9yh failed Q_v_attn_check_1
# 62f90c79da5c7deee5339c22 : R_22WDCbBbp6wzTOC failed Q_v_attn_check_1
# 62ecb2993d7ecd89154af5d4 : R_1jE9OvO2Htzyd3G failed Q_v_attn_check_1
# 5d338bb02381b7001761694e : R_2fChCYTanAFY71e failed Q_v_attn_check_1
# 5eea18fc3e537f0c21f2e9df : R_3GkODGvPCzd0j7k failed Q_v_attn_check_1
# 5d61a3a5f923dd0001d0370f : R_ZKoPV88yoMksuDT failed Q_habits_attn_check
# 6268a3f5379f921275a284f1 : R_1pDWVhd0SZFYPCz failed Q_v_attn_check_1
# 610c8dcba54f40dae1c50278 : R_2uHV0LkS9eDT27A failed Q_v_attn_check_1
# 5f9d6c8b87770828f1f08fbe : R_25zrMIk8UziY4cS failed Q_v_attn_check_1
# 5e3cc28a194a520c0c128f13 : R_3rOhwItOA8S89XB failed Q_v_attn_check_1
# 60d22b95ea12a89273fde27d : R_3KZaT2ltMRHoaMj failed Q_v_attn_check_1
# 60c80a0fb4b86678ad903cc1 : R_vwSiPlWRFwUthbX failed Q_v_attn_check_1
# 5c12b0ba17e18d0001e7629e : R_2XiLRSXizUm6iqD failed Q_v_attn_check_1
# 60051d10e63710373daee6e7 : R_DiuzNQ8AOgPF0FH failed Q_v_attn_check_1
# 60e4a68fea6bb239a06fc072 : R_2ErUR3uhwtLwSwG failed Q_v_attn_check_1
# 615f54a5141128cf81b7e857 : R_3nVQMn2WqohjXKL failed Q_v_attn_check_1
# 604bfe99dcaa286218d25fca : R_3GwcPspvuObTvWx failed Q_v_attn_check_1
# 5da7825f634607001172ca6a : R_1PcRYXvqWNFFLjF failed Q-attn-number-21
# 5dcccec0092079953154f997 : R_2S7zChQurJcYpEr failed Q_v_attn_check_1
# 6118db4c1a46f468a792b912 : R_3NFgqu50nwcLqTz failed Q_v_attn_check_1
# 5ffe7a7aaacffc4ee5e6ef6b : R_wYTtNSiK1Jgxq25 failed Q_habits_attn_check
# 58dfaf76ba8a05000109eb66 : R_10GjUbdLgqEnKvm failed Q_v_attn_check_1
# 57334d427d01ed00098e8e69 : R_1LpNWuBvmc3fyRB failed Q_v_attn_check_1
# 5d5b0dd7c032a2001ad7cf5d : R_2aPjpWozvW74PVs failed Q_v_attn_check_1
# 62f875cb0bd095fcf778dd3a : R_2EGii9B7fTNIaLO failed Q_v_attn_check_1
# 60430fc782b5752a7ae8d797 : R_qI9LSU1d7o4V7vH failed Q_v_attn_check_1
# 62f690f77c6fe10beb13d7b9 : R_D7TkGjAC3rnXuNP failed Q_v_attn_check_1
# 5fd8e27b6feb8e0d22eb3bd0 : R_cNHfVY16zf4iSWd failed Q_v_attn_check_1
# 5dbb9407e0a6e81863526af7 : R_12ltFrxVCTnblk5 failed Q_v_attn_check_1
# 60fcb2b45504d8488ab13968 : R_3qJyFUxKcyKGCcc failed Q_v_attn_check_1
# 5cd1a619240bc80013310b4e : R_1IB3HWEoyBnE1ea failed Q_v_attn_check_1
# 5c022a94d183df000141f1e2 : R_3shnL3a4DWixVAZ failed Q_v_attn_check_1
# 62348c41368404b2ade8312b : R_27BExLCthLZHNxd failed Q_habits_attn_check
# 5e1f8fbfb202032c463f3e06 : R_3g8eaXG18n8CjFu failed Q-attn-number-21
# 629e112d75f3665c8362ab6f : R_SVhI6IyFD1ap1XX failed Q_v_attn_check_1
# 5beccd423b6489000156596f : R_2bHkBv5UalV1Zdg failed Q_v_attn_check_1
# 5fefefa4c9707d3516361c9c : R_3Jhf9kHakiezRJL failed Q_v_attn_check_1
# 5eadd3cf13f83a483b5b8c04 : R_2AWgr06A2rNEj5E failed Q_v_attn_check_1
# 5b883986f249560001686872 : R_dnegp2DfS8rXCgN failed Q_habits_attn_check
# 5de985cf1be52f0a75357332 : R_2wuj45rRudHlL7v failed Q_v_attn_check_1
# 5df416a57bf5722f9a501255 : R_3ReZMa54tKgL36z failed Q_v_attn_check_1
# 58642f4de16d530001b34622 : R_2aVmuumf1QYYOD7 failed Q_v_attn_check_1
# 6077cb38de8f5c783d413450 : R_33a0ovEhYIGSHge failed Q_v_attn_check_1
# 614dd661c1fb4b13a7e99d64 : R_1q2LdbGVLDtUcAh failed Q_v_attn_check_1
# 614f75c032f05a135099017b : R_27Im8fn2RgWuClK failed Q_v_attn_check_1
# 609f58e8af0f5f3acedd9806 : R_1f3Dc7CmrJIycaC failed Q_v_attn_check_1
# 5c6ef14c2cd3cb0001fadd0e : R_3qsRUtg0PeeEEyu failed Q_v_attn_check_1
# 614f59b138dc25a862faa6a7 : R_sor49mumI4qGHFn failed Q_v_attn_check_1
# 5a7618b18fe2dc0001057243 : R_1DAsp6k09FAx1Xu failed Q_v_attn_check_1
# 6108708cc133f82c35c00f12 : R_3CDwX3u29og851M failed Q_v_attn_check_1
# 5e3dbf3d216cf7000cfa0d29 : R_bClJnrz5eGOTiFz failed Q_v_attn_check_1
# 5993020a5f49420001caf86b : R_3Oo8Oq6YCoeGOZt failed Q_v_attn_check_1
# 5e29c3e725dcfd01cef9f474 : R_vN2VUAo6ufWzh8B failed Q_v_attn_check_1
# 580cab86b869700001d71628 : R_STbp9SpQia9R7Gh failed Q_v_attn_check_1
# 61647caff869db29c54fde2b : R_3PjKdGYzpmYIupf failed Q_v_attn_check_1
# 5dd5ff2080123f5afc05fe82 : R_1k2oBm3sWSqaN7R failed Q_v_attn_check_1
# 5e1f662de37cd92970aa3d9a : R_1MVXgpp2Lm122b9 failed Q_v_attn_check_1
# 6237ca974050879378c8fea8 : R_3HwgitppH7YHXT0 failed Q_v_attn_check_1
# 5dd8829941afe883821a94c4 : R_30w6bx7Y3nS2elZ failed Q_v_attn_check_1
# 6151c93f62e26ed6871a5fbd : R_2pXhhCwEw7uq04w failed Q_v_attn_check_1
# 5ff4df04eae543c810716ee6 : R_2sWSI6GfgEAK4vb failed Q_v_attn_check_1
# 5b774f493c1375000197ad11 : R_1pytfpqxkielVAI failed Q_v_attn_check_1
# 6168a6cdc303371392b9d9c8 : R_1gnpGyle4dHdsly failed Q_habits_attn_check
# 626966a12d29060d48439d01 : R_3nx996IFYAEbHhk failed Q_v_attn_check_1
# 5c8f8374e08a58000192a9ff : R_1kNQHswgvMM6OfZ failed Q_v_attn_check_1
# 62fff3a366f10202cc095b1e : R_9n0OGhG66SCisuZ failed Q_v_attn_check_1
# 632d8cb263e70b33a48d9612 : R_3CJiPAnExdMz01L failed Q_v_attn_check_1
# 5e7ba5cdf4c3fb1c99c55198 : R_1KqDr8TJ77dvVeq failed Q_v_attn_check_1
# 5726570ef2a83f000f6aea6d : R_6fAf6oTjWtK40yB failed Q_v_attn_check_1
# 592621a771d4fe00012ce948 : R_1FnbV0PwUTqspwY failed Q_v_attn_check_1
# 62dc684ed7cae74b8b1fae8d : R_2yggSIh0eJbxgqr failed Q_v_attn_check_1
# 5c6ae4c31b9d0e000190bacc : R_1rAZoOdQzRXz5wv failed Q_v_attn_check_1
# 5c90094e71f3100016181ea9 : R_1k0mO9IlpRKwVUL failed Q_v_attn_check_1
# 60fd85e2ef01930befa495a3 : R_NWj0mXbqxnZ4WeB failed Q_v_attn_check_1
# 62f35d57ce9f476a00bfa8f8 : R_wKOnVMb4V3bjqSd failed Q_v_attn_check_1
# 5fbfd130b6d531364fba8ed6 : R_1LvfSucXjzVfFvy failed Q_v_attn_check_1
# 62833eadf3baa3ef8a587e41 : R_2rk0jDQvnQ93Fw7 failed Q_v_attn_check_1
# 60fcd0f990314dce9c243fef : R_PIK1hQbNXDlluRH failed Q_v_attn_check_1
# 5ee5f7f771f86b333ba269de : R_1FKaPVUWiwKnxWF failed Q-attn-number-21
# 5efec7794ff2093d25ffa6d0 : R_2YIZmrTegjqoUax failed Q_v_attn_check_1
# 5bc4ff222c08740001316ed2 : R_OOvOQTCLANZdyKd failed Q_v_attn_check_1
# 6165d57d7256ba57447e76b5 : R_O8rEMSoU0jgGWlP failed Q_v_attn_check_1
# 5dd3bfcd8b8df139ce007928 : R_2dAyZgqtmVlPRY1 failed Q_v_attn_check_1
# 62e15dfab54f025985de6b5c : R_2U0k2WZkB5Sf00z failed Q_v_attn_check_1
# 629a5aa2d167a9b3546cd6d2 : R_tWYLK2SD9ZZjg7T failed Q_v_attn_check_1
# 6116ad70f49538954d8f45b9 : R_ptmUQvPJxBzSGOt failed Q_v_attn_check_1
# 5f24b0fc546c5a0c3c2e43b6 : R_3OfrRwzKm6kv5UV failed Q_v_attn_check_1
# 629f600f0e7c09ec275bfdc2 : R_3KSKKyVGQCuxkzQ failed Q_v_attn_check_1
# 6088c08b5db0d7af3daf4b69 : R_3g6jHaDYqJl2Gtn failed Q_v_attn_check_1
# 62dc6d329a5144ff8b61afb9 : R_UnWOMifbOVHzsU9 failed Q_v_attn_check_1
# 5e4044797946592823cbec2a : R_3nd8Ak4GW3v2mNi failed Q_v_attn_check_1
# 631f615694556038026f8847 : R_pH0EPm8AGkAJsC5 failed Q_v_attn_check_1
# 62ec1607cf0be424ae3e29d1 : R_3RfONxSPLFHg6aW failed Q_v_attn_check_1
# 62f22a88345999bb6c0fc9de : R_3m9xG6SmaWRHiBZ failed Q_v_attn_check_1
# 63153455849b153d56dd81db : R_2PAQk3ACPKNMn09 failed Q_habits_attn_check
# 62c0e760fe5cc4964a774900 : R_2Et2GUD4hte2VqA failed Q_v_attn_check_1
# 5b26da1934ffd00001b45d8d : R_3GeQX3N6FfG7jQM failed Q_v_attn_check_1
# 5cfe7510d987a800178eab1a : R_1kS6fYarS6i6yhf failed Q_v_attn_check_1
# 5d37d2861566530016a061de : R_3fCVbu8LQPkEtjX failed Q_v_attn_check_1
# 5c961ee66357fb0001ef4b4a : R_1GwT3wn5tziS9EU failed Q_v_attn_check_1
# 5fc70104446bb4123cfc7328 : R_2VJgOdXuRvFo7GX failed Q_v_attn_check_1
# 63114814292f4b1bd61e0635 : R_1LMebqVXLLlLSo5 failed Q_v_attn_check_1
# 616d9ef881036dfbfd63d2f4 : R_2xDlvD2I02CslDF failed Q_v_attn_check_1
# 62c61250e85c96fc1794c7db : R_3Djx0DBPrdaX8LQ failed Q_v_attn_check_1
# 62ac942e9a1ba60e6dc872eb : R_3g6H17ttDj5SzDc failed Q_v_attn_check_1
# 5e5214e745774623bd28289f : R_2Cw5Ur3CX2szQ0e failed Q-attn-number-21
# 5b9530390f85f600015705bf : R_1eLGcbP0KCjJqWa failed Q_v_attn_check_1
# 5fb090f5bc045b492643352d : R_TnF47rRpDgQPpKh failed Q_v_attn_check_1
# 60b96835d5cbb2261c7fd22c : R_30hMVWfLtzNxSDq failed Q_v_attn_check_1
# 5e987688953dbe093b3c9acc : R_a4qHD4yqwBtBhhn failed Q_habits_attn_check
# 61206e8d3e6a6ccdd064637c : R_e9h7vobHEkMOsrn failed Q_habits_attn_check
# 5febd397ad8fbad21bcd6182 : R_21alCsk4oxGTKUM failed Q-attn-number-21
# 62ff8c9ff1c92a7c721d3fcc : R_33D8mLfBu0KTe5S failed Q_v_attn_check_1
# 5d5497857aff650001a18c3c : R_cTOhlv1wy8ckTsZ failed Q_v_attn_check_1
# 62b0d24d95bc72be2f45c720 : R_1LFLw7bd3MaghyS failed Q-attn-number-21
# 5c747b0f181ad300113363ed : R_0oYU3AUa3rzhTQ5 failed Q-attn-number-21
# 5d8998025e8a740001d6e2f1 : R_2qrNS3IuqpubOzC failed Q_v_attn_check_1
# 62d4c5676e4f202832300e40 : R_1C2en2EbU6JNuw0 failed Q_v_attn_check_1
# 5df9846d76f45070feedf075 : R_3shLBYzMM26u09A failed Q_v_attn_check_1
# 5e7227c4e9253c1509f76f96 : R_1GyuAxLvPM8gCU9 failed Q_v_attn_check_1
# 5baa535fa3c9170001156197 : R_31sEgv0dlg45V8w failed Q_v_attn_check_1
# 603e97018512c2f752512f0b : R_bHpeCYR0rFzW1ep failed Q_v_attn_check_1
# 5dd9923922749791b319fc19 : R_3PtrqSbnvLdnevu failed Q_v_attn_check_1
# 5e28e8730fd86a0a19e084cd : R_1MWm2yPtpMDYCYi failed Q_v_attn_check_1
# 5d9f625aadd8690015e87c76 : R_2t3jkphpkkzVePc failed Q_v_attn_check_1
# 60fcf9abf635e9904cb7dca9 : R_1kGlodqbtjZCOqz failed Q_v_attn_check_1
# 60d3740f31606cb50e49f00c : R_YQbp3jpMLBACjBf failed Q_v_attn_check_1
# 5ba292385301b80001c71ba2 : R_3nwJluyQlJH70bX failed Q_v_attn_check_1
# 5b7c877f9dc643000172043d : R_TngKqCeey1kCN9v failed Q_v_attn_check_1
# 5eceed79840590300f53fa51 : R_2rC4JQyg5KowGC0 failed Q-attn-number-21
# 5a5da588f6c51700019527c4 : R_22xYDGih1ogLXre failed Q_v_attn_check_1
# 5dc1cd625fd2031344dfe43d : R_1LpQSZZ7LlkXMZB failed Q_v_attn_check_1
# 5ae75fb18ca3cc000109816e : R_d5YrNBDtzigW0SZ failed Q_v_attn_check_1
# 5be05da9b5be300001e54be5 : R_4J7BXkbDhCX4O8V failed Q-attn-number-21
# 6143af8721d1445864c4f6c8 : R_29o8E1EoMmrz9hS failed Q_v_attn_check_1
# 5f048576973f3709114b2fcd : R_2Sw7IXkZ4gzJ5i3 failed Q_v_attn_check_1
# 5e8362d4e122360951978fc8 : R_21AHfzoNSmEcq2R failed Q_v_attn_check_1
# 606a3cf263a18869ac8ee0ed : R_yJVH4JvuQoeDr5T failed Q_v_attn_check_1
# 5de1bfa4fc03e9213d6b146a : R_2s777Ug2vbJia97 failed Q_v_attn_check_1
# 5f5b0f1be585c32184a4cf35 : R_2c5e0QxjKscHsH2 failed Q_habits_attn_check
# 6104d73b7cdac0a47a905f0d : R_cuvfWbDQYtRhHDX failed Q_v_attn_check_1
# 62d0880f5ba6d972d1bfc63c : R_2yk0jXIyOIAepoi failed Q_v_attn_check_1
# 628f7e982aad1788d940317a : R_1DtDvrXfuHSoQwS failed Q_v_attn_check_1
# 610f326ceebada4236a67080 : R_bKF2T2MsbrrL97j failed Q_v_attn_check_1
# 62e153b9b4357cf4f7bd969a : R_1CdWh5kpk8RIePs failed Q_v_attn_check_1
# 6073640883b8547a9b73569a : R_3kBvrHhUAtNzfEt failed Q_v_attn_check_1
# 5d9264f527fdac00158fd876 : R_3Eyg26mYTIOLnC1 failed Q_v_attn_check_1
# 5f35554b3e58ff4e844795e9 : R_22Wj57WzpqmlYyu failed Q_v_attn_check_1
# 56797198c3041a0012b64b5e : R_3QQ6rw5NRP79ReZ failed Q_v_attn_check_1
# 62ee97a5b8575bcfc9259b2e : R_3k5uDnBHXcreJIl failed Q-attn-number-21
# 61539b3fa541b182c0fadde1 : R_1rq3IeUwqxsicTl failed Q_v_attn_check_1
# 5f2732c17f64f043dd83bdbb : R_0idmMjEZ8Yfya65 failed Q_v_attn_check_1
# 59d5c894c732930001d88b5e : R_30tPeggk2feUzvD failed Q_v_attn_check_1
# 5d8e46b78133dc00142ef00b : R_3k7fizR3jNeqTqG failed Q-attn-number-21
# 6108469c7d486eac3c1629d3 : R_31ax0EUhYC787de failed Q_v_attn_check_1
# 6095fc75ab1d101e060d808b : R_2cqOLes2YGzaO7t failed Q_v_attn_check_1
# 6325482a5da955ebe4a72c93 : R_u7HBa0lePFJ33BD failed Q_habits_attn_check
# 5e2610aad15fdb000c054503 : R_20ZJL30yekhjkjM failed Q_v_attn_check_1
# 60ff23cda322631215a27a59 : R_38Y05IS7iXiAUsV failed Q_v_attn_check_1
# 6238dfab577ecd4adb97a917 : R_TiR5ZfNtM0K0t2N failed Q_v_attn_check_1
# 5d41e832b0ca7200169d857e : R_1IQQpjLs20urRY9 failed Q-attn-number-21
# 5694e7b5e0c800000b5a3841 : R_bOCwd8a0QEKHOOl failed Q_v_attn_check_1
# 5d3102894f751200016161c0 : R_WrGNShI4rIMF5a9 failed Q_v_attn_check_1
# 62e97dfea1a1ef00cb9f0b10 : R_3MFgkpVCGiH3dmO failed Q_v_attn_check_1
# 5e4b1627e778a8030266480c : R_2fld3mSLjIxUlbx failed Q_v_attn_check_1
# 5e287b789061a504bf990894 : R_vjKWyv6cTaI3adb failed Q_v_attn_check_1
# 605ff0746397c26c436b88af : R_1fcGToy6MAELEUc failed Q_v_attn_check_1
# 5d8a64630ffb9c001746ca2c : R_3EAaGX1OOBkAoAf failed Q_v_attn_check_1
# 55b47001fdf99b615b12d66c : R_1jps4mrug26DOWV failed Q_v_attn_check_1
# 58d7896b4240e5000118f705 : R_VRqLBHo4LzqDLRD failed Q_v_attn_check_1
# 5e7a6846f0f631000a4e2b9d : R_3DkCtiT6mYFGv9b failed Q-attn-number-21
# 599de70d8a6cc5000128f980 : R_2Cm4o67chdXOQ3e failed Q_v_attn_check_1
# 5f5918b850e39f115fe81297 : R_3p5P5P1cvescPOW failed Q_v_attn_check_1
# 5f363a9a07d496680e6dfc49 : R_1JFKQs0KHdDsmol failed Q_v_attn_check_1
# 5d49a0b751695e0001a188a8 : R_VIRBmrCePeAYK1H failed Q_v_attn_check_1
# 5eb0bbbc0be27c183500b45d : R_2BrEZXZZUsVIOwR failed Q_v_attn_check_1
# 5a94c0b7b5e2110001c6891e : R_2ruoLb7eJFwVGYa failed Q_v_attn_check_1
# 61088a6f0372d8a146faa96b : R_31LdOzNo3dXHNfU failed Q_v_attn_check_1
# 62fd0bc538d70b87550691f7 : R_se82pGlMA4U5zWh failed Q_v_attn_check_1
# 63241d16ec316ec3f8f615d1 : R_2rI7pl1PTXEjxcA failed Q_habits_attn_check
# 60fcdb9569a7966b511cf122 : R_2wRej8vAwCbb9Em failed Q_v_attn_check_1
# 5fa2050042e91e3c2bae0ec2 : R_2Qnh48DTMuZxnns failed Q_v_attn_check_1
# 5d31266f466cc90019de4e43 : R_1jJkgI88swPO8rL failed Q_v_attn_check_1
# 62f32d1cd0736183ffe64dc7 : R_2RXh4gKqFq6F9sa failed Q_v_attn_check_1
# 5d63179aa3b94d0001da4bb6 : R_1QbxyZRnCNM4mVn failed Q_v_attn_check_1
# 6310bdd0c04dd21ec4d97496 : R_1LFh1bzcq5WWtgH failed Q_v_attn_check_1
# 5c0de097af19750001df3313 : R_C1Y27Bq9WzdiLol failed Q_habits_attn_check
# 5f15ba922eed6a21fe83e78a : R_293KDQX029uMGOT failed Q_v_attn_check_1
# 614f6bad672ef7cf5ecfd965 : R_26hl2rw5E1BRST5 failed Q_v_attn_check_1
# 6151e479b4ee16668948c7f2 : R_2uNDc5Z0z2iAMnH failed Q_v_attn_check_1
# 5ff2240a2f567121402762e6 : R_3PpilsuEOttKjb1 failed Q_v_attn_check_1
# 6317457367495fa60d79d84e : R_2YYwF6f6Yt3OTPa failed Q_v_attn_check_1
# 612e41fb25de530ea83df0bc : R_1HkT79FhhMMh8hJ failed Q_v_attn_check_1
# 62d6c2cd1416387d1e7d691a : R_1Dql0e7nx3scY4s failed Q_v_attn_check_1
# 60e9e8092cfc1f464753dd71 : R_r0fwoKg8bSAYWhr failed Q_v_attn_check_1
# 6272eccadd98507271a651c7 : R_290ITrYMJU1FOsz failed Q_v_attn_check_1
# 5e45db9c36b2e20888a64f5f : R_2Tt7HpS1MvrupGu failed Q_v_attn_check_1
# 5fee99daeae54318b087e9b5 : R_1ClPCENnX0wnsrV failed Q_v_attn_check_1
# 5debce5335575a2bed69acc6 : R_3gYDCYsjgc57tGk failed Q_v_attn_check_1
# 6101b5f7b7de35910a926c62 : R_83dew434qr4TPFv failed Q_v_attn_check_1
# 60c701efc22d9a81c8003de7 : R_3Ia7JhE0PIbJVNv failed Q_v_attn_check_1
# 5ef9338e3fa1390009d94b76 : R_ulFQieg8KaRhGjT failed Q_habits_attn_check
# 5fbcba5a9b4bfe18cd49abea : R_2RNT9LHy0wGwwAK failed Q_v_attn_check_1
# 60a7c4434b322876925afaa3 : R_3gT2xmHvmqDuUmm failed Q_v_attn_check_1
# 622ab357bb3af819f2e5df3b : R_PuLXjMgnyf7zwv7 failed Q_v_attn_check_1
# 6102efc4b15dcadb22d8d1d4 : R_2dSywkpnAqSTxXm failed Q-attn-number-21
# 5c580c3dd3cc6b0001d9ffbf : R_2yqJBbetgNmksi9 failed Q_habits_attn_check
# 5c205371da51990001e17313 : R_3r0cGN7VoPUv4s2 failed Q_v_attn_check_1
# 5ea45eb9abef8a07bcced2bc : R_1DCoAvGS50Ez2bv failed Q_v_attn_check_1
# 5f179bd584e8e802ef9c187d : R_bgD2y7VeFfVL9kd failed Q_v_attn_check_1
# 62ac80c7bb52b8c5e8ba266d : R_3jcfOmXarYPKvtV failed Q_v_attn_check_1
# 567adef5b7d79a0012b26b95 : R_XzxXCTkQ8CxqJu9 failed Q_habits_attn_check
# 5ed2279607f2230009a0e205 : R_sApaXzghV2175xn failed Q_v_attn_check_1
# 629f4800dfb8c7c86f69a67e : R_URcdY15GElZ8Dkt failed Q_habits_attn_check
# 62e1e3f92efe886934aebdc4 : R_1Q5u8w0eP3gVSUL failed Q_v_attn_check_1
# 5ef42ba59401801d9f859e2d : R_1DHGAvNg1KLHw9v failed Q_v_attn_check_1
# 5bd03c4308a62c0001f963e9 : R_2YFLjidoJYhcqKH failed Q_v_attn_check_1
# 5c616465b672de0001fd3ac6 : R_27lre6tjLAQGs8D failed Q_v_attn_check_1
# 5e7a5c9d7567f003b57b85e9 : R_3ktE5XrNOx4aJlh failed Q_v_attn_check_1
# 60fe79b330eb2d8f0fc7b3af : R_3fOHS2ynn7O1y5y failed Q_v_attn_check_1
# 5fc389e2c42314669487410a : R_1FhuqzmmkWLKQ8T failed Q_v_attn_check_1
# 56b2f64c9b4875000b2099f2 : R_2OJTPK07WhwnV4H failed Q-attn-number-21
# 628de7e8ff1744a9717d7883 : R_30pMWQusvXyz3B7 failed Q_v_attn_check_1
# 62b0560cd5ce4b0cc13d2c3a : R_VU79PIAryctj5Qt failed Q_v_attn_check_1
# 5c094736a33f6c0001e9c70c : R_BCWXc8EzqSDFesp failed Q_v_attn_check_1
# 5ca2d3dd010c73001606b7d8 : R_3s0yhNrXmiMnVcx failed Q-attn-number-21
# 60ff8160e8f2227f8b200510 : R_1lsB5CdPooPxbIL failed Q_v_attn_check_1
# 611431b8dfc10c8bb1393e8c : R_1dAf0onQ3a29ISY failed Q_habits_attn_check
# 5dc9f3a0e2633171257d503e : R_3s7C0WfomJxeaQo failed Q_v_attn_check_1
# 5ed953ff9a8d504d5c451db0 : R_1pEfA8vxteUk2hN failed Q_v_attn_check_1
# 5c4f8e27232d020001303d05 : R_31i10qNsyMxve9N failed Q_v_attn_check_1
# 5b49eba46a4f840001f77485 : R_21oh8LI5UqLIbzA failed Q_v_attn_check_1
# 5ab8026547a9f7000153a324 : R_31m9E9xrl4U0bix failed Q_v_attn_check_1
# 5f74e752c78e6211cc4efaaa : R_2ccI9vTXahJSvJ7 failed Q_v_attn_check_1
# 62a7c4d5266dfb89bf94fec8 : R_3PpYXSiznDHmtAL failed Q_v_attn_check_1
# 630af3d7a31683dc91d38135 : R_3Dpel2dHOBqD1vY failed Q_v_attn_check_1
# 5ddafb0f2e4a05a5ff7759c9 : R_1QilWKUDrv5GO5j failed Q_v_attn_check_1
# 632dd45fb49858b31338c11c : R_YWZMsQB1gW4e6Xf failed Q_v_attn_check_1
# 5fbb2540b981f7c1e0fca5ff : R_3dVQ8y5CsOjp6xP failed Q_v_attn_check_1
# 616d0c1b16a0437469b6cd74 : R_1i4EMwc16C5Fzz2 failed Q_v_attn_check_1
# 6150cce0c62a1423bf29fc52 : R_8deXBqAXpKlt0S5 failed Q_v_attn_check_1
# 6316ae12fc4fe7b5e89d2123 : R_3lzRmR7nDxWJUsL failed Q-attn-number-21
# 6315a102cb675027354ef5d8 : R_1EZmIzX2VlX5NJ2 failed Q_v_attn_check_1
# 5ef3a5fff378fa1321125965 : R_2S8g1cy8TmQ63MF failed Q_v_attn_check_1
# 60fd3cd100cfd3da1b3b9e11 : R_12lk74QclkmTWWC failed Q_v_attn_check_1
# 5d0792471f48fb00185613cf : R_3dKvsHlQCYewME8 failed Q_v_attn_check_1
# 62e4b6f21f7c164777c6eb67 : R_1ONutwPhMUiY4zv failed Q_v_attn_check_1
# 62aa265d938c612f7c8361e3 : R_25ZxB7AxOmVgD80 failed Q_v_attn_check_1
# 631f5497988d131d110c4014 : R_3njXhyeZu4Rjlph failed Q_v_attn_check_1
# 5ff6c57463af76282ac64916 : R_3EDWX00dty32the failed Q_v_attn_check_1
# 5e9fc65dee2ccf178f0e413f : R_3M3xE67CMnaehcu failed Q_v_attn_check_1
# 60fd1ef37a8a9201cbf7d588 : R_3hlrlePWPsAmzyY failed Q_v_attn_check_1
# 60bebdec81297725b80fd773 : R_2ujKXsMhD7bic3n failed Q_v_attn_check_1
# 607331e66524baf7ddfaae21 : R_2aJjwYOi3ip7FfW failed Q_v_attn_check_1
# 5d829da97f572900184a7cb1 : R_2R4B0dB9SLITNxA failed Q_v_attn_check_1
# 5f8b30e56acaf60de565ef4f : R_1M6h0nAJNM5vL1t failed Q_v_attn_check_1
# 6164d593d3783a588b11017b : R_swiAKQggh1yZVhD failed Q_v_attn_check_1
# 5dcca657854936945d68eaa9 : R_21BMEW1CSkWpVo6 failed Q_v_attn_check_1
# 6277cfc36a7df487202fe926 : R_3oL9pCuYIKHt6an failed Q_v_attn_check_1
# 0.93 = 3715/4016 respondents passed all attention checks

# %%
print('dropping responses from participants who failed any attention check')
df = df[df['passed_attn_checks']]
N = len(df)
print('N=%s' % N)
# Out:
# dropping responses from participants who failed any attention check
# N=3715

# %% [markdown]
# Can now drop columns 'Finished' and 'PROLIFIC_PID' and columns corresponding to attention checks.

# %%
df = df.drop([
    'PROLIFIC_PID','Finished',
    'Q-attn-number-21',
    'Q_habits_attn_check',
    'Q_v_attn_check_1',
    'passed_attn_checks',
], axis=1)
df.head(3)
# Out:
#   Duration (in seconds)         RecordedDate         ResponseId  \
# 6                   215  2022-09-12 09:25:01  R_3dNdOyEHwO3X5Tg
# 7                   176  2022-09-12 09:29:21  R_1r7Zvnp6IL6dFXo
# 8                   358  2022-09-12 09:29:38  R_1JIXl9IZdC0IxJt
#
#   Q_online_shopping Q_takeout_food Q_online_groceries Q_v_0_why_no  \
# 6                 2              1                  4          NaN
# 7                 3              4                  5          NaN
# 8                 2              4                  4          NaN
#
#   Q_v_0_why_no_4_TEXT Q_v_1 Q_v_1_why_no  ... Q_state Q_comments  \
# 6                 NaN     1          NaN  ...      31        NaN
# 7                 NaN     1          NaN  ...       5        NaN
# 8                 NaN     3          NaN  ...      11        NaN
#
#                    STUDY_ID online_shopping takeout_food_delivery  \
# 6  631f4adf9c7bc459e1650eb6            True                  True
# 7  631f4adf9c7bc459e1650eb7            True                  True
# 8  631f4adf9c7bc459e1650eb7            True                  True
#
#   online_groceries prescription_medications_delivery  \
# 6             True                              True
# 7            False                              True
# 8             True                              True
#
#   last_minute_groceries_delivery liquor_store_delivery questions_asked
# 6                           True                  True             NaN
# 7                          False                  True             NaN
# 8                           True                  True             NaN
#
# [3 rows x 831 columns]

# %% [markdown]
# How long did the survey take people on average?
#
# (in minutes)
# Use Median (50%) because there were outliers that took a while.

# %%
(df['Duration (in seconds)'].astype(int).describe()/60).rename('minutes')
# Out:
# count    61.916667
# mean      5.570000
# std       3.789526
# min       1.050000
# 25%       3.500000
# 50%       4.616667
# 75%       6.333333
# max      77.933333
# Name: minutes, dtype: float64

# %% [markdown]
# Save cleaned data to file.

# %%
print('saving data (N=%s) to %s...' % (len(df),cleaned_data_filepath))
df.to_csv(cleaned_data_filepath, index=False)
print('...saved')
# Out:
# saving data (N=3715) to ../data/sample-preprocessed.csv...
# ...saved

# %%
# reading from file
clean_df = pd.read_csv(cleaned_data_filepath)
print('N=%s responses' % len(clean_df))
clean_df.head(3)
# Out:
# N=3715 responses
#    Duration (in seconds)         RecordedDate         ResponseId  \
# 0                    215  2022-09-12 09:25:01  R_3dNdOyEHwO3X5Tg
# 1                    176  2022-09-12 09:29:21  R_1r7Zvnp6IL6dFXo
# 2                    358  2022-09-12 09:29:38  R_1JIXl9IZdC0IxJt
#
#    Q_online_shopping  Q_takeout_food  Q_online_groceries Q_v_0_why_no  \
# 0                  2               1                   4          NaN
# 1                  3               4                   5          NaN
# 2                  2               4                   4          NaN
#
#   Q_v_0_why_no_4_TEXT  Q_v_1 Q_v_1_why_no  ... Q_state  Q_comments  \
# 0                 NaN      1          NaN  ...      31         NaN
# 1                 NaN      1          NaN  ...       5         NaN
# 2                 NaN      3          NaN  ...      11         NaN
#
#                    STUDY_ID online_shopping  takeout_food_delivery  \
# 0  631f4adf9c7bc459e1650eb6            True                   True
# 1  631f4adf9c7bc459e1650eb7            True                   True
# 2  631f4adf9c7bc459e1650eb7            True                   True
#
#    online_groceries  prescription_medications_delivery  \
# 0              True                               True
# 1             False                               True
# 2              True                               True
#
#    last_minute_groceries_delivery  liquor_store_delivery  questions_asked
# 0                            True                   True              NaN
# 1                           False                   True              NaN
# 2                            True                   True              NaN
#
# [3 rows x 831 columns]
